# %%
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
import os
import json
import shutil
import magic
import re
import sys
from opencc import OpenCC
from openai import OpenAI
from pydantic import BaseModel
from typing import List, Dict
from natsort import natsorted

# Add Pydantic model for JSON schema
class RenameSchema(BaseModel):
    old_to_new: Dict[str, str]


class AudioFileValidator:
    """Strict audio file validation excluding non-audio files"""
    AUDIO_EXTENSIONS = {
        '.dsd', '.dff', '.dsf', '.wav', '.aiff', '.aif',
        '.flac', '.alac', '.dts', '.thd', '.mlp', '.mqa', 
        '.tak', '.ape', '.mp3', '.aac', '.m4a', '.ogg', '.wma'
    }
    
    def is_audio_file(self, filename: str) -> bool:
        ext = os.path.splitext(filename)[1].lower()
        return ext in self.AUDIO_EXTENSIONS

class FileRenameMap(BaseModel):
    old_to_new: Dict[str, str]  # Direct filename mapping

def clean_filename(name: str) -> str:
    """Basic sanitization without changing order"""
    return re.sub(r'[<>:"/\\|?*]', '', name)

def process_album(album_dir: str):
    client = OpenAI(
        api_key=os.getenv("PERPLEXITY_API_KEY"),
        base_url="https://api.perplexity.ai"
    )
    
    try:
        # Get original file list in directory order
        files = natsorted([
            f for f in os.listdir(album_dir) 
            if AudioFileValidator().is_audio_file(f)
        ])
        
        # Get direct filename mapping from LLM
        response = client.chat.completions.create(
            model="sonar-pro",
        messages=[
            {
                "role": "system",
                "content": (
                    "You are a music file alignment specialist. Follow this precise workflow:\n\n"
                    
                    "**Step 1: Filename Analysis**\n"
                    "- For each filename, extract ANY existing track number using pattern matching\n"
                    "- Note: Track numbers may be prefixed (01 Song), suffixed (Song 01), or missing\n\n"
                    
                    "**Step 2: Official Tracklist Verification**\n"
                    "1. Search MusicBrainz/Discogs for OFFICIAL tracklist using album name\n"
                    "2. Cross-reference with streaming platforms (Spotify/Apple Music)\n"
                    "3. Confirm language: Traditional Chinese for Chinese content, English otherwise\n\n"
                    
                    "**Step 3: Track Alignment & Renaming**\n"
                    "- For each file, determine the official track name and number by searching reputable sources such as MusicBrainz, Discogs, YesAsia, or official artist/label websites. Use Google if needed. Search for the album’s official tracklist.\n"
                    "- STRICT RULE: The renamed file must correspond to the actual song content, not just the filename. Do not guess based on filename alone-verify using track duration, lyrics, or other metadata if possible.\n"
                    "- If the official track number/order is found, use a 2-digit zero-padded number (e.g., 01, 02) as a prefix in the new filename, matching the album’s official order.\n"
                    "- If NO official track number/order can be found for a song, do NOT include any number in the new filename-just use the clean official track title.\n"
                    "- Always preserve the original file extension.\n"
                    "\n"
                    "**Examples:**\n"
                    "1. Official tracklist: 01 Happy Birthday, 02 Merry Christmas, 03 Little Tea Pot\n"
                    "   Input: ['Merry Christmas.flac', 'Happy Birthday.flac', '03 Little Tea Pot.flac']\n"
                    "   Output: {\n"
                    "     'Merry Christmas.flac': '02 Merry Christmas.flac',\n"
                    "     'Happy Birthday.flac': '01 Happy Birthday.flac',\n"
                    "     '03 Little Tea Pot.flac': '03 Little Tea Pot.flac'\n"
                    "   }\n"
                    "\n"
                    "2. Official tracklist: 青春修練手冊, 魔法城堡, 寵愛 (no numbers published)\n"
                    "   Input: ['Track 1.mp3', 'Magic Castle.flac', '宠爱.ape']\n"
                    "   Output: {\n"
                    "     'Track 1.mp3': '青春修練手冊.mp3',\n"
                    "     'Magic Castle.flac': '魔法城堡.flac',\n"
                    "     '宠爱.ape': '寵愛.ape'\n"
                    "   }\n"
                    "\n"
                    "3. If you cannot verify the official order for a song, do NOT invent a number-just use the official title.\n"
                    "\n"
                    "THIS IS CRITICAL: Only assign numbers if you can confirm the official track order from at least one reputable source. Otherwise, use the clean title only."

                    "**Step 4: Validation Checks**\n"
                    "- Ensure ALL original files are mapped 1:1\n"
                    "- Verify extensions remain identical (.dsf → .dsf)\n"
                    "- Reject duplicate track numbers\n\n"
                    
                    "**Output Format Requirements**\n"
                    "{\n"
                    "  \"old_to_new\": {\n"
                    "    \"[原始文件名1]\": \"01 正式曲名1.扩展名\",\n" 
                    "    \"[原始文件名2]\": \"02 正式曲名2.扩展名\"\n"
                    "  }\n"
                    "}\n"
                    "- Track numbers: 2-digit zero-padded\n"
                    "- Special cases:\n"
                    "  - Live: Append \"(Live)\"\n"
                    "  - Remix: Append \"(Remix)\"\n"
                    "  - Instrumental: Use \"Instrumental\" artist"
                )
            },
            {
                "role": "user",
                "content": (
                    "Clean and align these files while PRESERVING THEIR INPUT ORDER:\n"
                    f"{json.dumps(files)}\n\n"
                    "Critical Reminders:\n"
                    "1. NEVER reorder files - use input order as track sequence\n"
                    "2. Prioritize official names from verified sources\n"
                    "3. Strict Traditional Chinese for Chinese-language content\n"
                    "4. Return COMPLETE JSON - no truncation"
                )
            }
        ],
            temperature=0.0,
            response_format={
                "type": "json_schema",
                "json_schema": {
                    "schema": RenameSchema.model_json_schema()  # Proper schema reference
                }
            }
        )
        
        rename_map = FileRenameMap.model_validate_json(
            response.choices[0].message.content
        )
        
        # Create new directory under 'new_albums' at the same level as album_dir
        parent_dir = os.path.dirname(album_dir)
        new_albums_dir = os.path.join(parent_dir, "new_albums")
        os.makedirs(new_albums_dir, exist_ok=True)
        new_dir = os.path.join(new_albums_dir, os.path.basename(album_dir))
        os.makedirs(new_dir, exist_ok=True)
        
        # Copy files with new names in original order
        for old_name in files:
            if old_name not in rename_map.old_to_new:
                continue

            new_name = clean_filename(rename_map.old_to_new[old_name])
            shutil.copy2(
            os.path.join(album_dir, old_name),
            os.path.join(new_dir, new_name)
            )
            print(f"Copied: {old_name} → {new_name}")

        # Convert to Traditional Chinese if needed
        convert_traditional_chinese(new_dir)
        
    except Exception as e:
        print(f"Error processing {album_dir}: {str(e)}")

def convert_traditional_chinese(path: str):
    """Optional Chinese conversion"""
    cc = OpenCC('s2t')
    for filename in os.listdir(path):
        base, ext = os.path.splitext(filename)
        new_base = cc.convert(base)
        if new_base != base:
            os.rename(
                os.path.join(path, filename),
                os.path.join(path, f"{clean_filename(new_base)}{ext}")
            )

def main():
    music_root = os.path.abspath("F://Albums")
    if not os.path.exists(music_root):
        print(f"Path not found: {music_root}")
        return
        
    for album in os.listdir(music_root):
        album_path = os.path.join(music_root, album)
        if os.path.isdir(album_path):
            print(f"\nProcessing: {album}")
            process_album(album_path)

if __name__ == "__main__":
    main()
# Out:
# Processing: [Bruno Mars] 24K Magic
# Copied: _Bruno Mars-24K Magic.dsf → 01 24K Magic.dsf
# Copied: _Bruno Mars-Calling All My Lovelies.dsf → 02 Calling All My Lovelies.dsf
# Copied: _Bruno Mars-Chunky.dsf → 03 Chunky.dsf
# Copied: _Bruno Mars-Finesse.dsf → 04 Finesse.dsf
# Copied: _Bruno Mars-Perm.dsf → 05 Perm.dsf
# Copied: _Bruno Mars-Straight Up & Down.dsf → 06 Straight Up & Down.dsf
# Copied: _Bruno Mars-That's What I Like.dsf → 07 That's What I Like.dsf
# Copied: _Bruno Mars-Too Good To Say Goodbye.dsf → 08 Too Good To Say Goodbye.dsf
# Copied: _Bruno Mars-Versace On The Floor.dsf → 09 Versace On The Floor.dsf
#
# Processing: [Taylor Swift] Midnights
# Copied: 01 - Taylor Swift - Lavender Haze.flac → 01 Lavender Haze.flac
# Copied: 02 - Taylor Swift - Maroon.flac → 02 Maroon.flac
# Copied: 03 - Taylor Swift - Anti-Hero.flac → 03 Anti-Hero.flac
# Copied: 04 - Taylor Swift - Snow On The Beach.flac → 04 Snow On The Beach.flac
# Copied: 05 - Taylor Swift - You're On Your Own, Kid.flac → 05 You're On Your Own, Kid.flac
# Copied: 06 - Taylor Swift - Midnight Rain.flac → 06 Midnight Rain.flac
# Copied: 07 - Taylor Swift - Question.flac → 07 Question.flac
# Copied: 08 - Taylor Swift - Vigilante Shit.flac → 08 Vigilante Shit.flac
# Copied: 09 - Taylor Swift - Bejeweled.flac → 09 Bejeweled.flac
# Copied: 10 - Taylor Swift - Labyrinth.flac → 10 Labyrinth.flac
# Copied: 11 - Taylor Swift - Karma.flac → 11 Karma.flac
# Copied: 12 - Taylor Swift - Sweet Nothing.flac → 12 Sweet Nothing.flac
# Copied: 13 - Taylor Swift - Mastermind.flac → 13 Mastermind.flac
#
# Processing: [The Weekend] After Hours
# Copied: The Weeknd - After Hours.dsf → 13 After Hours.dsf
# Copied: The Weeknd - Alone Again.dsf → 01 Alone Again.dsf
# Copied: The Weeknd - Blinding Lights.dsf → 09 Blinding Lights.dsf
# Copied: The Weeknd - Escape From LA.dsf → 06 Escape From LA.dsf
# Copied: The Weeknd - Hardest to Love.dsf → 03 Hardest to Love.dsf
# Copied: The Weeknd - Heartless.dsf → 07 Heartless.dsf
# Copied: The Weeknd - In You Eyes.dsf → 10 In Your Eyes.dsf
# Copied: The Weeknd - Repeat Ater Me.dsf → 12 Repeat After Me (Interlude).dsf
# Copied: The Weeknd - Save Your Tears.dsf → 11 Save Your Tears.dsf
# Copied: The Weeknd - Scared to Live.dsf → 04 Scared to Live.dsf
# Copied: The Weeknd - Snowchild.dsf → 05 Snowchild.dsf
# Copied: The Weeknd - Too Late.dsf → 02 Too Late.dsf
# Copied: The Weeknd - Until I Bleed Out.dsf → 14 Until I Bleed Out.dsf
# Copied: The Weeknd - faith.dsf → 08 Faith.dsf
#
# Processing: [江海迦] AGA
# Copied: AGA-Better Me(Home demo ： Butterscotch).dsf → AGA-Better Me (Home Demo Butterscotch).dsf
# Copied: AGA-One Day At A Time.dsf → AGA-One Day At A Time.dsf
# Copied: AGA-一釐米.dsf → AGA-一釐米.dsf
# Copied: AGA-哈囉(Live Piano version).dsf → AGA-哈囉 (Live Piano Version).dsf
# Copied: AGA-哈囉.dsf → AGA-哈囉.dsf
# Copied: AGA-問好.dsf → AGA-問好.dsf
# Copied: AGA-我願意(Home demo ： Wedding).dsf → AGA-我願意 (Home Demo Wedding).dsf
# Copied: AGA-能說不的祕密(Unusual Mix).dsf → AGA-能說不的祕密 (Unusual Mix).dsf
# Copied: AGA-能說不的祕密.dsf → AGA-能說不的祕密.dsf
#
# Processing: [江海迦] Agatha
# Copied: AGA&陳奕迅-Special One (feat. Eason Chan).dsf → Special One (feat. Eason Chan).dsf
# Copied: AGA-CityPop.dsf → CityPop.dsf
# Copied: AGA-Count to Ten.dsf → Count to Ten.dsf
# Copied: AGA-Julie(Demo Version).dsf → Julie (Demo Version).dsf
# Copied: AGA-MIZU(Acoustic Version).dsf → MIZU (Acoustic Version).dsf
# Copied: AGA-MIZU.dsf → MIZU.dsf
# Copied: AGA-Miss u Goodbye.dsf → Miss u Goodbye.dsf
# Copied: AGA-Sorry.dsf → Sorry.dsf
# Copied: AGA-The Lovers.dsf → The Lovers.dsf
# Copied: AGA-Tomorrow.dsf → Tomorrow.dsf
# Copied: AGA-Why You.dsf → Why You.dsf
# Copied: AGA-理性與任性之間.dsf → 理性與任性之間.dsf
# Copied: 姜濤 Keung To&AGA-I Know (feat. AGA).dsf → I Know (feat. AGA).dsf
#
# Processing: [The Weekend] Beauty Behind The Madness
# Copied: _The Weeknd&Ed Sheeran-Dark Times(Explicit).dsf → Dark Times (feat. Ed Sheeran).dsf
# Copied: _The Weeknd&Labrinth-Losers(Explicit).dsf → Losers (feat. Labrinth).dsf
# Copied: _The Weeknd&Lana Del Rey-Prisoner(Explicit).dsf → Prisoner (feat. Lana Del Rey).dsf
# Copied: _The Weeknd-Acquainted(Explicit).dsf → Acquainted.dsf
# Copied: _The Weeknd-Angel(Explicit).dsf → Angel.dsf
# Copied: _The Weeknd-As You Are(Explicit).dsf → As You Are.dsf
# Copied: _The Weeknd-Can't Feel My Face.dsf → Can't Feel My Face.dsf
# Copied: _The Weeknd-Earned It(Fifty Shades Of Grey).dsf → Earned It (Fifty Shades of Grey).dsf
# Copied: _The Weeknd-In The Night(Explicit).dsf → In the Night.dsf
# Copied: _The Weeknd-Often(Explicit).dsf → Often.dsf
# Copied: _The Weeknd-Real Life(Explicit).dsf → Real Life.dsf
# Copied: _The Weeknd-Shameless(Explicit).dsf → Shameless.dsf
# Copied: _The Weeknd-Tell Your Friends(Explicit).dsf → Tell Your Friends.dsf
# Copied: _The Weeknd-The Hills(Explicit).dsf → The Hills.dsf
#
# Processing: [Taylor Swift] evermore
# Copied: 01 - Taylor Swift - willow.flac → 01 willow.flac
# Copied: 02 - Taylor Swift - champagne problems.flac → 02 champagne problems.flac
# Copied: 03 - Taylor Swift - gold rush.flac → 03 gold rush.flac
# Copied: 04 - Taylor Swift - ‘tis the damn season.flac → 04 'tis the damn season.flac
# Copied: 05 - Taylor Swift - tolerate it.flac → 05 tolerate it.flac
# Copied: 06 - Taylor Swift - no body, no crime.flac → 06 no body, no crime.flac
# Copied: 07 - Taylor Swift - happiness.flac → 07 happiness.flac
# Copied: 08 - Taylor Swift - dorothea.flac → 08 dorothea.flac
# Copied: 09 - Taylor Swift - coney island.flac → 09 coney island.flac
# Copied: 10 - Taylor Swift - ivy.flac → 10 ivy.flac
# Copied: 11 - Taylor Swift - cowboy like me.flac → 11 cowboy like me.flac
# Copied: 12 - Taylor Swift - long story short.flac → 12 long story short.flac
# Copied: 13 - Taylor Swift - marjorie.flac → 13 marjorie.flac
# Copied: 14 - Taylor Swift - closure.flac → 14 closure.flac
# Copied: 15 - Taylor Swift - evermore.flac → 15 evermore.flac
# Copied: 16 - Taylor Swift - right where you left me.flac → 16 right where you left me.flac
# Copied: 17 - Taylor Swift - it’s time to go.flac → 17 it's time to go.flac
#
# Processing: [Beyond] 20週年 大地
# Copied: Beyond - 不需要太懂.dsf → 不需要太懂.dsf
# Copied: Beyond - 九十年代的憂傷.dsf → 九十年代的憂傷.dsf
# Copied: Beyond - 今天有我.dsf → 今天有我.dsf
# Copied: Beyond - 你知道我的迷惘.dsf → 你知道我的迷惘.dsf
# Copied: Beyond - 和自己的心比賽.dsf → 和自己的心比賽.dsf
# Copied: Beyond - 大地.dsf → 大地.dsf
# Copied: Beyond - 短暫的溫柔.dsf → 短暫的溫柔.dsf
# Copied: Beyond - 破壞遊戲的孩子.dsf → 破壞遊戲的孩子.dsf
# Copied: Beyond - 送給不懂環保的人.dsf → 送給不懂環保的人.dsf
#
# Processing: [Beyond] Best of the Best
# Copied: 01 - BEYOND - Amani.dsf → 01 Amani.dsf
# Copied: 02 - BEYOND - 光輝歲月.dsf → 02 光輝歲月.dsf
# Copied: 03 - BEYOND - 再見理想.dsf → 03 再見理想.dsf
# Copied: 04 - BEYOND - 不再猶豫.dsf → 04 不再猶豫.dsf
# Copied: 05 - BEYOND - 俾面派對.dsf → 05 俾面派對.dsf
# Copied: 06 - BEYOND - 灰色軌跡.dsf → 06 灰色軌跡.dsf
# Copied: 07 - BEYOND - 大地.dsf → 07 大地.dsf
# Copied: 08 - BEYOND - 舊日的足跡.dsf → 08 昔日舞曲.dsf
# Copied: 09 - BEYOND - 歲月無聲.dsf → 09 歲月無聲.dsf
# Copied: 10 - BEYOND - 祕密警察.dsf → 10 秘密警察.dsf
# Copied: 11 - BEYOND - 真的愛妳.dsf → 11 真的愛妳.dsf
# Copied: 12 - BEYOND - 喜歡妳.dsf → 12 喜歡妳.dsf
# Copied: 13 - BEYOND - 冷雨夜.dsf → 13 冷雨夜.dsf
# Copied: 14 - BEYOND - 願諒我今天.dsf → 14 願我能.dsf
#
# Processing: [Final Fantasy] 最終幻想10
#
# Processing: [Instrumental] 66聲手搖鈴作品集
# Copied: 01.Water Music.dsf → 01 Water Music.dsf
# Copied: 02.Canon.dsf → 02 Canon in D.dsf
# Copied: 03.Jesus bleibet meine Freude, BWV 147.dsf → 03 Jesu, Joy of Man's Desiring, BWV 147.dsf
# Copied: 04.Arabesque.dsf → 04 Arabesque No. 1.dsf
# Copied: 05.Liebesträume.dsf → 05 Liebesträume No. 3.dsf
# Copied: 06.The Nutcracker; March.dsf → 06 The Nutcracker, Op. 71 March.dsf
# Copied: 07.The Nutcracker; Dance of the suger-plum tairy.dsf → 07 The Nutcracker, Op. 71 Dance of the Sugar Plum Fairy.dsf
# Copied: 08.The Nutcracker; Dance of the flutes.dsf → 08 The Nutcracker, Op. 71 Dance of the Reed Flutes.dsf
# Copied: 09.The Nutcracker; Trepak.dsf → 09 The Nutcracker, Op. 71 Trepak.dsf
# Copied: 10.Gavotte.dsf → 10 Gavotte.dsf
# Copied: 11.Passacaille.dsf → 11 Passacaille.dsf
# Copied: 12.Radetzky-Marsch.dsf → 12 Radetzky March, Op. 228.dsf
#
# Processing: [Instrumental ] 泛藍調調 (Kind of Blue)
# Copied: All Blues.flac → 04 All Blues.flac
# Copied: Blue in Green.flac → 03 Blue in Green.flac
# Copied: Flamenco Sketches.flac → 05 Flamenco Sketches.flac
# Copied: Freddie Freeloader.flac → 02 Freddie Freeloader.flac
# Copied: So What.flac → 01 So What.flac
#
# Processing: [Instrumental] BLACK ORPHEUS
# Copied: 01.Gentle Rain.dsf → 01 Gentle Rain.dsf
# Copied: 02.Small Teardrop.dsf → 02 Small Teardrop.dsf
# Copied: 03.Triste.dsf → 03 Triste.dsf
# Copied: 04.How Insensitive.dsf → 04 How Insensitive.dsf
# Copied: 05.Sonho Carioca.dsf → 05 Sonho Carioca.dsf
# Copied: 06.Once I Loved.dsf → 06 Once I Loved.dsf
# Copied: 07.Assanhado.dsf → 07 Assanhado.dsf
# Copied: 08.Black Orpheus.dsf → 08 Black Orpheus.dsf
# Copied: 09.Bole-Bole.dsf → 09 Bole-Bole.dsf
# Copied: 10.Desafinado.dsf → 10 Desafinado.dsf
# Copied: 11.Doce de Coco.dsf → 11 Doce de Coco.dsf
# Copied: 12.This Happy Madness.dsf → 12 This Happy Madness.dsf
#
# Processing: [Instrumental] Beloved - 莫扎特鋼琴奏鳴曲 (11.2MHz DSD)
# Copied: Piano Sonata in A Major, KV331 I.Andante grazioso.dsf → 01 Andante grazioso.dsf
# Copied: Piano Sonata in A Major, KV331 II.Menuetto & Trio.dsf → 02 Menuetto & Trio.dsf
# Copied: Piano Sonata in A Major, KV331 III.Alla Turca, Allegretto.dsf → 03 Alla Turca, Allegretto.dsf
# Copied: Piano Sonata in B-flat Major, KV570 I.Allegro.dsf → 01 Allegro.dsf
# Copied: Piano Sonata in B-flat Major, KV570 II.Adagio.dsf → 02 Adagio.dsf
# Copied: Piano Sonata in B-flat Major, KV570 III.Allegretto.dsf → 03 Allegretto.dsf
# Copied: Piano Sonata in C Major, KV330 I.Allegro moderato.dsf → 01 Allegro moderato.dsf
# Copied: Piano Sonata in C Major, KV330 II.Andante cantabile.dsf → 02 Andante cantabile.dsf
# Copied: Piano Sonata in C Major, KV330 III.Allegretto.dsf → 03 Allegretto.dsf
# Copied: Piano Sonata in C Major, KV545 I.Allegro.dsf → 01 Allegro.dsf
# Copied: Piano Sonata in C Major, KV545 II.Andante.dsf → 02 Andante.dsf
# Copied: Piano Sonata in C Major, KV545 III.Rondo, Allegretto.dsf → 03 Rondo, Allegretto.dsf
# Copied: Piano Sonata in C Minor, KV457 I.Molto allegro.dsf → 01 Molto allegro.dsf
# Copied: Piano Sonata in C Minor, KV457 II.Adagio.dsf → 02 Adagio.dsf
# Copied: Piano Sonata in C Minor, KV457 III.Allegro assai, agitato.dsf → 03 Allegro assai, agitato.dsf
# Copied: Piano Sonata in D Major, KV311 I.Allegro con spirito.dsf → 01 Allegro con spirito.dsf
# Copied: Piano Sonata in D Major, KV311 II.Andante con espressione.dsf → 02 Andante con espressione.dsf
# Copied: Piano Sonata in D Major, KV311 III.Rondeau, Allegro.dsf → 03 Rondeau, Allegro.dsf
# Copied: Piano Sonata in E-flat Major, KV282 I.Adagio.dsf → 01 Adagio.dsf
# Copied: Piano Sonata in E-flat Major, KV282 II.Menuetto I & II.dsf → 02 Menuetto I & II.dsf
# Copied: Piano Sonata in E-flat Major, KV282 III.Allegro.dsf → 03 Allegro.dsf
# Copied: Piano Sonata in F Major, KV332 I.Allegro.dsf → 01 Allegro.dsf
# Copied: Piano Sonata in F Major, KV332 II.Adagio.dsf → 02 Adagio.dsf
# Copied: Piano Sonata in F Major, KV332 III.Allegro assai.dsf → 03 Allegro assai.dsf
#
# Processing: [Instrumental] Red Dead Redemption 2
#
# Processing: [周杰倫] 十一月的蕭邦
# Copied: 周杰倫 - 一路向北.dsf → 一路向北.dsf
# Copied: 周杰倫 - 夜曲.dsf → 夜曲.dsf
# Copied: 周杰倫 - 楓.dsf → 楓.dsf
# Copied: 周杰倫 - 浪漫手機.dsf → 浪漫手機.dsf
# Copied: 周杰倫 - 藍色風暴.dsf → 藍色風暴.dsf
# Copied: 周杰倫 - 逆鱗.dsf → 逆鱗.dsf
# Copied: 周杰倫 - 飄移.dsf → 飄移.dsf
# Copied: 周杰倫 - 麥芽糖.dsf → 麥芽糖.dsf
# Copied: 周杰倫 - 黑色毛衣.dsf → 黑色毛衣.dsf
# Copied: 周杰倫&Lara梁心頤 - 珊瑚海.dsf → 珊瑚海.dsf
# Copied: 周杰倫&林邁可 - 四面楚歌.dsf → 四面楚歌.dsf
#
# Processing: [容祖兒] 廣東精選 DSD
# Copied: 01 - 心淡.dsf → 01 心淡.dsf
# Copied: 02 - 習慣失戀.dsf → 02 習慣失戀.dsf
# Copied: 03 - 逃避你.dsf → 03 逃避你.dsf
# Copied: 04 - 痛愛.dsf → 04 痛愛.dsf
# Copied: 05 - 想得太遠.dsf → 05 想得太遠.dsf
# Copied: 06 - 明日恩典.dsf → 06 明日恩典.dsf
# Copied: 07 - 16號愛人.dsf → 07 16號愛人.dsf
# Copied: 02 - 走不掉.dsf → 02 走不掉.dsf
# Copied: 03 - 墮落天堂.dsf → 03 墜落天堂.dsf
# Copied: 04 - 稀有品種.dsf → 04 稀有品種.dsf
# Copied: 05 - 該不該.dsf → 05 該不該.dsf
# Copied: 06 - 咖啡.dsf → 06 咖啡.dsf
# Copied: 07 - 驕傲.dsf → 07 驕傲.dsf
# Copied: 08 - 為什麼愛是這樣.dsf → 08 為什麼愛是這樣.dsf
# Copied: 09 - 禮物.dsf → 09 禮物.dsf
# Copied: 10 - 我得你.dsf → 10 我得你.dsf
# Copied: 11 - 相愛很難.dsf → 11 相愛很難.dsf
# Copied: 12 - 從頭到尾.dsf → 12 從頭到尾.dsf
# Copied: 13 - 日與夜.dsf → 13 日與夜.dsf
#
# Processing: [Beyond] 光輝歲月
#
# Processing: [鄧紫棋] 睡皇后
# Copied: G.E.M.鄧紫棋 - WHY.dsf → G.E.M.鄧紫棋 - WHY.dsf
# Copied: G.E.M.鄧紫棋 - 岩石裏的花.dsf → G.E.M.鄧紫棋 - 岩石裡的花.dsf
# Copied: G.E.M.鄧紫棋 - 睡皇后.dsf → G.E.M.鄧紫棋 - 睡皇后.dsf
#
# Processing: [張學友] 愛你多一些精選
# Copied: 01 - Jacky Cheung - 一顆不變心.dsf → 01 一顆不變心.dsf
# Copied: 02 - Jacky Cheung - 每天愛你多一些.dsf → 02 每天愛你多一些.dsf
# Copied: 03 - Jacky Cheung - 李香蘭.dsf → 03 李香蘭.dsf
# Copied: 04 - Jacky Cheung - Cry.dsf → 04 Cry.dsf
# Copied: 05 - Jacky Cheung - 忘情冷雨夜.dsf → 05 忘情冷雨夜.dsf
# Copied: 06 - Jacky Cheung - 太陽星辰.dsf → 06 太陽星晨.dsf
# Copied: 07 - Jacky Cheung - 夕陽醉了.dsf → 07 夕陽醉了.dsf
# Copied: 08 - Jacky Cheung - 再度重遇妳.dsf → 08 再度重遇妳.dsf
# Copied: 09 - Jacky Cheung - 祇願一生愛一人.dsf → 09 祇願一生愛一人.dsf
# Copied: 10 - Jacky Cheung - Linda.dsf → 10 Linda.dsf
# Copied: 11 - Jacky Cheung - 親親.dsf → 11 親親.dsf
# Copied: 12 - Jacky Cheung - 再愛上妳.dsf → 12 再愛上妳.dsf
#
# Processing: [Coldplay] A Head Full of Dreams
# Copied: Coldplay-A Head Full of Dreams.dsf → A Head Full of Dreams.dsf
# Copied: Coldplay-A Sky Full of Stars(Live At the Enmore Theatre, Sydney).dsf → A Sky Full of Stars (Live).dsf
# Copied: Coldplay-Adventure of a Lifetime.dsf → Adventure of a Lifetime.dsf
# Copied: Coldplay-Amazing Day.dsf → Amazing Day.dsf
# Copied: Coldplay-Army of One.dsf → Army of One.dsf
# Copied: Coldplay-Birds.dsf → Birds.dsf
# Copied: Coldplay-Clocks(Live At the Enmore Theatre, Sydney).dsf → Clocks (Live).dsf
# Copied: Coldplay-Colour Spectrum.dsf → Colour Spectrum.dsf
# Copied: Coldplay-Everglow.dsf → Everglow.dsf
# Copied: Michael Jackson - It's The Falling In Love.dsf → It's The Falling In Love.dsf
# Copied: Michael Jackson - Off The Wall.dsf → Off The Wall.dsf
# Copied: Michael Jackson - Quincy Jones Interview #2.dsf → Quincy Jones Interview #2.dsf
# Copied: Michael Jackson - Quincy Jones Interview #3.dsf → Quincy Jones Interview #3.dsf
# Copied: Michael Jackson - Rock With You (1).dsf → Rock With You.dsf
# Copied: Michael Jackson - She's Out Of My Life (1).dsf → She's Out Of My Life.dsf
# Copied: Michael Jackson - Voice-over Intro Quincy Jones Interview #4／Quincy Jones Interview.dsf → Voice-over Intro Quincy Jones Interview #4.dsf
# Copied: Michael Jackson - Voice-over Intro Quincy Jones Interview／Quincy Jones Interview #1.dsf → Voice-over Intro Quincy Jones Interview #1.dsf
# Copied: Michael Jackson - Voice-over Intro Rod Temperton Interview／Rod Temperton Interview.dsf → Voice-over Intro Rod Temperton Interview.dsf
# Copied: Michael Jackson - Voice-over Intro ＂Don't Stop 'Til You Get Enough (Original Demo From 1978)＂.dsf → Voice-over Intro Don't Stop 'Til You Get Enough (Original Demo From 1978).dsf
# Copied: Michael Jackson - Voice-over Intro ＂Workin' Day And Night (Original Demo From 1978)＂.dsf → Voice-over Intro Workin' Day And Night (Original Demo From 1978).dsf
# Copied: Michael Jackson - Workin' Day And Night (Original Demo From 1978).dsf → Workin' Day And Night (Original Demo From 1978).dsf
# Copied: Michael Jackson - Workin' Day And Night.dsf → Workin' Day And Night.dsf
#
# Processing: [Taylor Swift] Red (Taylor's Version)
# Copied: Taylor Swift & Chris Stapleton - I Bet You Think About Me (feat. Chris Stapleton) (Taylor’s Version) (From The Vault).dsf → I Bet You Think About Me (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift & Ed Sheeran - Everything Has Changed (feat. Ed Sheeran) (Taylor’s Version).dsf → Everything Has Changed (Taylor's Version).dsf
# Copied: Taylor Swift & Ed Sheeran - Run (feat. Ed Sheeran) (Taylor's Version) (From The Vault).dsf → Run (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift & Gary Lightbody -The Last Time (feat. Gary Lightbody of Snow Patrol) (Taylor’s Version).dsf → The Last Time (Taylor's Version).dsf
# Copied: Taylor Swift & Phoebe Bridgers - Nothing New (feat. Phoebe Bridgers) (Taylor’s Version) (From The Vault).dsf → Nothing New (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - 22 (Taylor’s Version).dsf → 22 (Taylor's Version).dsf
# Copied: Taylor Swift - All Too Well (Taylor’s Version).dsf → All Too Well (Taylor's Version).dsf
# Copied: Taylor Swift - All Too Well (Ten Minute Version) (Taylor’s Version) (From The Vault).dsf → All Too Well (Ten Minute Version) (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - Babe (Taylor’s Version) (From The Vault).dsf → Babe (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - Begin Again (Taylor’s Version).dsf → Begin Again (Taylor's Version).dsf
# Copied: Taylor Swift - Better Man (Taylor’s Version) (From The Vault).dsf → Better Man (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - Come Back...Be Here (Taylor’s Version).dsf → Come Back...Be Here (Taylor's Version).dsf
# Copied: Taylor Swift - Forever Winter (Taylor’s Version) (From The Vault) .dsf → Forever Winter (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - Girl At Home (Taylor’s Version).dsf → Girl At Home (Taylor's Version).dsf
# Copied: Taylor Swift - Holy Ground (Taylor’s Version).dsf → Holy Ground (Taylor's Version).dsf
# Copied: Taylor Swift - I Almost Do (Taylor’s Version).dsf → I Almost Do (Taylor's Version).dsf
# Copied: Taylor Swift - I Knew You Were Trouble (Taylor’s Version).dsf → I Knew You Were Trouble (Taylor's Version).dsf
# Copied: Taylor Swift - Message In A Bottle (Taylor’s Version) (From The Vault).dsf → Message In A Bottle (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - Red (Taylor’s Version).dsf → Red (Taylor's Version).dsf
# Copied: Taylor Swift - Ronan (Taylor’s Version).dsf → Ronan (Taylor's Version).dsf
# Copied: Taylor Swift - Sad Beautiful Tragic (Taylor’s Version).dsf → Sad Beautiful Tragic (Taylor's Version).dsf
# Copied: Taylor Swift - Starlight (Taylor’s Version).dsf → Starlight (Taylor's Version).dsf
# Copied: Taylor Swift - State Of Grace (Acoustic Version) (Taylor’s Version).dsf → State Of Grace (Acoustic Version) (Taylor's Version).dsf
# Copied: Taylor Swift - State Of Grace (Taylor’s Version).dsf → State Of Grace (Taylor's Version).dsf
# Copied: Taylor Swift - Stay Stay Stay (Taylor’s Version).dsf → Stay Stay Stay (Taylor's Version).dsf
# Copied: Taylor Swift - The Lucky One (Taylor’s Version).dsf → The Lucky One (Taylor's Version).dsf
# Copied: Taylor Swift - The Moment I Knew (Taylor’s Version).dsf → The Moment I Knew (Taylor's Version).dsf
# Copied: Taylor Swift - The Very First Night (Taylor’s Version) (From The Vault).dsf → The Very First Night (Taylor's Version) (From The Vault).dsf
# Copied: Taylor Swift - We Are Never Ever Getting Back Together (Taylor’s Version).dsf → We Are Never Ever Getting Back Together (Taylor's Version).dsf
# Copied: Taylor Swift -Treacherous (Taylor’s Version).dsf → Treacherous (Taylor's Version).dsf
#
# Processing: [Taylor Swift] reputation
# Copied: Taylor Swift & Ed Sheeran & Future -End Game.dsf → 02 End Game (feat. Ed Sheeran & Future).dsf
# Copied: Taylor Swift - ...Ready For It？.dsf → 01 ...Ready For It.dsf
# Copied: Taylor Swift - Call It What You Want.dsf → 14 Call It What You Want.dsf
# Copied: Taylor Swift - Dancing With Our Hands Tied.dsf → 11 Dancing with Our Hands Tied.dsf
# Copied: Taylor Swift - Delicate.dsf → 05 Delicate.dsf
# Copied: Taylor Swift - Don't Blame Me.dsf → 04 Don't Blame Me.dsf
# Copied: Taylor Swift - Dress.dsf → 12 Dress.dsf
# Copied: Taylor Swift - Getaway Car.dsf → 09 Getaway Car.dsf
# Copied: Taylor Swift - Gorgeous.dsf → 08 Gorgeous.dsf
# Copied: Taylor Swift - I Did Something Bad .dsf → 03 I Did Something Bad.dsf
# Copied: 02 - Cass Phang - 罷不來.dsf → 02 砌不來.dsf
# Copied: 03 - Cass Phang - 重回那天那地.dsf → 03 重回那天那地.dsf
# Copied: 04 - Cass Phang - 你最近怎樣.dsf → 04 你最近怎樣.dsf
# Copied: 05 - Cass Phang - 你說.dsf → 05 你說.dsf
# Copied: 06 - Cass Phang - 咬脣.dsf → 06 咬唇.dsf
# Copied: 07 - Cass Phang - 我不知.dsf → 07 我不知.dsf
# Copied: 08 - Cass Phang - 一起.dsf → 08 一起.dsf
# Copied: 09 - Cass Phang - 我不會.dsf → 09 我不會.dsf
# Copied: 10 - Cass Phang - 放眼將來.dsf → 10 放眼將來.dsf
# Copied: 11 - Cass Phang - 只當是個夢.dsf → 11 只當是個夢.dsf
#
# Processing: [張惠妹] DSD
# Copied: 02 - A-Mei - 原來你什麼都不要.dsf → 02 原來你什麼都不要.dsf
# Copied: 03 - A-Mei - 讓每個人都心碎.dsf → 03 讓每個人都心碎.dsf
# Copied: 04 - A-Mei - 哭砂.dsf → 04 哭砂.dsf
# Copied: 05 - A-Mei - 解脫.dsf → 05 解脫.dsf
# Copied: 06 - A-Mei - 站在高崗上.dsf → 06 站在高崗上.dsf
# Copied: 07 - A-Mei - 沒有煙抽的日子.dsf → 07 沒有煙抽的日子.dsf
# Copied: 08 - A-Mei - 藍天.dsf → 08 藍天.dsf
# Copied: 09 - A-Mei - 不要告別.dsf → 09 不要告別.dsf
# Copied: 10 - A-Mei - 哭不出來.dsf → 10 哭不出來.dsf
# Copied: 11 - A-Mei - Bad Boy.dsf → 11 Bad Boy.dsf
# Copied: 12 - A-Mei - 空中的夢想家.dsf → 12 空中的夢想家.dsf
# Copied: 13 - A-Mei - 灰姑娘.dsf → 13 灰姑娘.dsf
# Copied: 14 - A-Mei - 旅程.dsf → 14 旅程.dsf
# Copied: 15 - A-Mei - 剪愛.dsf → 15 剪愛.dsf
#
# Processing: [彭羚] 完全因你
# Copied: 01 - Cass Phang - 隔世情.dsf → 01 隔世情.dsf
# Copied: 02 - Cass Phang - 完全因你.dsf → 02 完全因你.dsf
# Copied: 03 - Cass Phang - 小玩意.dsf → 03 小玩意.dsf
# Copied: 04 - Cass Phang - 如夢初醒.dsf → 04 如夢初醒.dsf
# Copied: 05 - Cass Phang - 彷如隔世.dsf → 05 彷如隔世.dsf
# Copied: 06 - Cass Phang - 未完的小說.dsf → 06 未完的小說.dsf
# Copied: 07 - Cass Phang - 出色女子.dsf → 07 出色女子.dsf
# Copied: 08 - Cass Phang - 仍然是最愛你.dsf → 08 仍然是最愛你.dsf
# Copied: 09 - Cass Phang - 喜歡最喜歡你.dsf → 09 喜歡最喜歡你.dsf
# Copied: 10 - Cass Phang - 有著你……多麼美.dsf → 10 有著你……多麼美.dsf
# Copied: 11 - Cass Phang - 如果得不到愛情.dsf → 11 如果得不到愛情.dsf
# Copied: 12 - Cass Phang - 不許眼兒再下雨.dsf → 12 不許眼兒再下雨.dsf
# Copied: 13 - Cass Phang - 等得太久.dsf → 13 等得太久.dsf
# Copied: 14 - Cass Phang - 戀火.dsf → 14 戀火.dsf
# Copied: 15 - Cass Phang - 等你到白頭（巫啟賢合唱）.dsf → 15 等你到白頭（巫啟賢合唱）.dsf
#
# Processing: [林俊傑] JJ陸
# Copied: Always Online.dsf → Always Online.dsf
# Copied: Cries In A Distance.dsf → Cries In A Distance.dsf
# Copied: Sixology(口白).dsf → Sixology (口白).dsf
# Copied: 不潮不用花錢.dsf → 不潮不用花錢.dsf
# Copied: 主角.dsf → 主角.dsf
# Copied: 小酒窩.dsf → 小酒窩.dsf
# Copied: 愛與希望.dsf → 愛與希望.dsf
# Copied: 我還想她.dsf → 我還想她.dsf
# Copied: 期待愛.dsf → 期待愛.dsf
# Copied: 由你選擇.dsf → 由你選擇.dsf
# Copied: 街道.dsf → 街道.dsf
# Copied: 醉赤壁.dsf → 醉赤壁.dsf
# Copied: 黑武士.dsf → 黑武士.dsf
# Copied: 點一把火炬.dsf → 點一把火燒.dsf
#
# Processing: [林俊傑] 學不會
# Copied: Cinderella.dsf → Cinderella.dsf
# Copied: Love U U.dsf → Love U U.dsf
# Copied: We Together.dsf → We Together.dsf
# Copied: 不存在的情人.dsf → 不存在的情人.dsf
# Copied: 學不會.dsf → 學不會.dsf
# Copied: 故事細膩.dsf → 故事細膩.dsf
# Copied: 獨奏.dsf → 獨奏.dsf
# Copied: 白羊夢.dsf → 白羊夢.dsf
# Copied: 白蘭花.dsf → 白蘭花.dsf
# Copied: 那些你很冒險的夢.dsf → 那些你很冒險的夢.dsf
# Copied: 陌生老朋友.dsf → 陌生老朋友.dsf
# Copied: 靈魂的共鳴.dsf → 靈魂的共鳴.dsf
#
# Processing: [林俊傑] 她說 概念自選輯
#
# Processing: [林子祥, 陳奕迅] 拉闊壓軸
#
# Processing: [梅艷芳] 牀前明月光
# Copied: 02 女兒紅.dsf → 02 女兒紅.dsf
# Copied: 03 想得開.dsf → 03 想得開.dsf
# Copied: 04 挑剔.dsf → 04 挑剔.dsf
# Copied: 06 眼中釘.dsf → 06 眼中釘.dsf
# Copied: 07 愛上狼的羊.dsf → 07 愛上狼的羊.dsf
# Copied: 08 飄零.dsf → 08 飄零.dsf
# Copied: 09 東西.dsf → 09 東西.dsf
# Copied: 10 空城.dsf → 10 空城.dsf
#
# Processing: [梅艷芳] 赤色梅艷芳
# Copied: 01 赤的疑惑.dsf → 01 赤的疑惑.dsf
# Copied: 02 迎風上路.dsf → 02 迎風上路.dsf
# Copied: 03 珍珠指環的約誓.dsf → 03 珍珠指環的約誓.dsf
# Copied: 04 再共舞.dsf → 04 再共舞.dsf
# Copied: 05 不必想昨天.dsf → 05 不必想昨天.dsf
# Copied: 06 赤的衝擊.dsf → 06 赤的衝擊.dsf
# Copied: 07 交出我的心.dsf → 07 交出我的心.dsf
# Copied: 08 殘月碎春風.dsf → 08 殘月碎春風.dsf
# Copied: 09 一個字.dsf → 09 一個字.dsf
# Copied: 10 相逢未晚.dsf → 10 相逢未晚.dsf
# Copied: 11 傳說.dsf → 11 傳說.dsf
# Copied: 12 千年女王.dsf → 12 千年女王.dsf
#
# Processing: [梅艷芳] 飛躍舞臺
# Copied: 01 留住你今晚.dsf → 01 留住你今晚.dsf
# Copied: 03 寂寞的心.dsf → 03 寂寞的心.dsf
# Copied: 04 獨愛荊途.dsf → 04 獨愛荊途.dsf
# Copied: 05 不信愛有罪.dsf → 05 不信愛有罪.dsf
# Copied: 06 他令我改變.dsf → 06 他令我改變.dsf
# Copied: 07 逝去的愛.dsf → 07 逝去的愛.dsf
# Copied: 08 不許再回頭.dsf → 08 不許再回頭.dsf
# Copied: 09 莫逃避.dsf → 09 莫逃避.dsf
# Copied: 10 發電一千Volt.dsf → 10 發電一千Volt.dsf
# Copied: 11 點起你慾望.dsf → 11 點起你慾望.dsf
# Copied: 12 今晚記住我.dsf → 12 今晚記住我.dsf
#
# Processing: [王菲] Di Dar
# Copied: 01 - Di-Dar.dsf → 01 Di-Dar.dsf
# Copied: 02 - 假期.dsf → 02 假期.dsf
# Copied: 03 - 迷路.dsf → 03 迷路.dsf
# Copied: 04 - 曖昧.dsf → 04 曖昧.dsf
# Copied: 05 - 或者.dsf → 05 或者.dsf
# Copied: 06 - 我想.dsf → 06 我想.dsf
# Copied: 07 - 享受.dsf → 07 享受.dsf
# Copied: 08 - 一半.dsf → 08 一半.dsf
# Copied: 09 - 無題.dsf → 09 無題.dsf
# Copied: 10 - 流星.dsf → 10 流星.dsf
#
# Processing: [Blackpink] BLACKPINK IN YOUR AREA
# Copied: BLACKPINK-AS IF IT'S YOUR LAST.dsf → As If It's Your Last.dsf
# Copied: BLACKPINK-BOOMBAYAH.dsf → Boombayah.dsf
# Copied: BLACKPINK-DDU-DU DDU-DU.dsf → DDU-DU DDU-DU.dsf
# Copied: BLACKPINK-FOREVER YOUNG.dsf → Forever Young.dsf
# Copied: BLACKPINK-PLAYING WITH FIRE.dsf → Playing With Fire.dsf
# Copied: BLACKPINK-REALLY.dsf → Really.dsf
# Copied: BLACKPINK-SEE U LATER.dsf → See U Later.dsf
# Copied: BLACKPINK-STAY.dsf → Stay.dsf
# Copied: BLACKPINK-WHISTLE.dsf → Whistle.dsf
#
# Processing: [Beyond] 樂與怒
# Copied: 01 - 我是憤怒.dsf → 01 我是憤怒.dsf
# Copied: 02 - 爸爸媽媽.dsf → 02 爸爸媽媽.dsf
# Copied: 03 - 和平與愛.dsf → 03 和平與愛.dsf
# Copied: 04 - 命運是你家.dsf → 04 命運是你家.dsf
# Copied: 05 - 全是愛 (This Is Love).dsf → 05 全是愛.dsf
# Copied: 06 - 海闊天空.dsf → 06 海闊天空.dsf
# Copied: 07 - 狂人山莊.dsf → 07 狂人山莊.dsf
# Copied: 08 - 妄想.dsf → 08 妄想.dsf
# Copied: 09 - 完全地愛吧.dsf → 09 完全地愛吧.dsf
# Copied: 10 - 情人.dsf → 10 情人.dsf
# Copied: 11 - 走不開的快樂.dsf → 11 走不開的快樂.dsf
# Copied: 12 - 無無謂.dsf → 12 無無謂.dsf
# Copied: Beyond - 全是愛.dsf → 全是愛.dsf
# Copied: Beyond - 命運是你家.dsf → 命運是你家.dsf
# Copied: Beyond - 和平與愛.dsf → 和平與愛.dsf
# Copied: Beyond - 妄想.dsf → 妄想.dsf
# Copied: Beyond - 完全地愛吧.dsf → 完全地愛吧.dsf
# Copied: Beyond - 情人.dsf → 情人.dsf
# Copied: Beyond - 我是憤怒.dsf → 我是憤怒.dsf
# Copied: Beyond - 海闊天空.dsf → 海闊天空.dsf
# Copied: Beyond - 無無謂.dsf → 無無謂.dsf
# Copied: Beyond - 爸爸媽媽.dsf → 爸爸媽媽.dsf
# Copied: Beyond - 狂人山莊.dsf → 狂人山莊.dsf
# Copied: Beyond - 走不開的快樂.dsf → 走不開的快樂.dsf
#
# Processing: [劉德華] 只知道此刻愛妳
# Copied: 02 飛鳥.dsf → 02 飛鳥.dsf
# Copied: 03 對所愛奉獻.dsf → 03 對所愛奉獻.dsf
# Copied: 04 七色白日夢.dsf → 04 七色白日夢.dsf
# Copied: 06 但願未流淚.dsf → 06 但願未流淚.dsf
# Copied: 08 我願獨行.dsf → 08 我願獨行.dsf
# Copied: 09 愛的終秒.dsf → 09 愛的終秒.dsf
# Copied: 10 願與妳.dsf → 10 願與妳.dsf
#
# Processing: [王菲] 唱遊
# Copied: 01. 感情生活.wav → 01 感情生活.wav
# Copied: 02. 臉.wav → 02 臉.wav
# Copied: 03. 色誡.wav → 03 色誡.wav
# Copied: 04. 半途而廢.wav → 04 半途而廢.wav
# Copied: 05. 飛.wav → 05 飛.wav
# Copied: 07. 小聰明.wav → 07 小聰明.wav
# Copied: 08. 醒不來.wav → 08 醒不來.wav
# Copied: 09. 紅豆.wav → 09 紅豆.wav
# Copied: 10. 童.wav → 10 童.wav
# Copied: 11. 麻醉 (Remix).wav → 11 麻醉 (Remix).wav
# Copied: 12. EYES ON ME.wav → 12 EYES ON ME.wav
# Copied: 13. 原諒自己 [Cantonese].wav → 13 原諒自己 [Cantonese].wav
# Copied: 14. 償還 [Cantonese].wav → 14 償還 [Cantonese].wav
# Copied: 15. 情誡 [Cantonese].wav → 15 情誡 [Cantonese].wav
#
# Processing: [李克勤] 極品之選
# Copied: 01 - 月半小夜曲 Half Moon Nocturnal.dsf → 01 月半小夜曲.dsf
# Copied: 02 - 大會堂演奏廳 Music Hall of City Hall.dsf → 02 大會堂演奏廳.dsf
# Copied: 03 - 一生掛念妳 I Will Love You Forever.dsf → 03 一生掛念妳.dsf
# Copied: 04 - My Shirley.dsf → 04 My Shirley.dsf
# Copied: 05 - 深深深 Deep Deep Deep.dsf → 05 深深深.dsf
# Copied: 06 - 藍月亮 Blue Moon.dsf → 06 藍月亮.dsf
# Copied: 07 - 夏日之神話 The Myth Of Summer.dsf → 07 夏日之神話.dsf
# Copied: 08 - 一生不變 Never Change In Life.dsf → 08 一生不變.dsf
# Copied: 09 - 後會有期 Hope To See You Again.dsf → 09 後會有期.dsf
# Copied: 10 - 心上人 My Angel.dsf → 10 心上人.dsf
# Copied: 11 - 一千零一夜 1001 Night.dsf → 11 一千零一夜.dsf
# Copied: 12 - 眷戀 Love.dsf → 12 癡戀.dsf
# Copied: 13 - 紅樓夢 Our Old Love Story.dsf → 13 紅樓夢.dsf
# Copied: 14 - 此情此境 At This Moment.dsf → 14 此情此境.dsf
# Copied: 15 - 只想您會意 I Just Wish You Like.dsf → 15 只想您會意.dsf
# Copied: 16 - 紅日 The Sun.dsf → 16 紅日.dsf
#
# Processing: [李克勤] 此情此境
# Copied: 01. 深深深.dsf → 01 深深深.dsf
# Copied: 02. 邊緣少年.dsf → 02 邊緣少年.dsf
# Copied: 03. 聽說你失戀.dsf → 03 聽說你失戀.dsf
# Copied: 04. 足球小旋風.dsf → 04 足球小旋風.dsf
# Copied: 05. 此情此境.dsf → 05 此情此境.dsf
# Copied: 06. 天作之合.dsf → 06 天作之合.dsf
# Copied: 07. 藍月亮.dsf → 07 藍月亮.dsf
# Copied: 08. 浪漫長路.dsf → 08 浪漫長路.dsf
# Copied: 09. 心上人.dsf → 09 心上人.dsf
# Copied: 10. 心中的宇宙.dsf → 10 心中的宇宙.dsf
#
# Processing: [林憶蓮] Re Workz
# Copied: 04 Stay.dsf → 04 Stay.dsf
# Copied: 05 下雨天.dsf → 05 下雨天.dsf
# Copied: 06 喜樂.dsf → 06 喜樂.dsf
# Copied: 07 哭.dsf → 07 哭.dsf
# Copied: 09 點唱機.dsf → 09 點唱機.dsf
# Copied: 10 願.dsf → 10 願.dsf
#
# Processing: [林憶蓮] Ultimate Sound SACD series
# Copied: 01 - 三更夜半.dsf → 01 三更夜半.dsf
# Copied: 02 - 夜了…沒有藉口.dsf → 02 夜了…沒有藉口.dsf
# Copied: 03 - 還有.dsf → 03 還有.dsf
# Copied: 04 - 你是我的男人.dsf → 04 你是我的男人.dsf
# Copied: 05 - 講多錯多.dsf → 05 講多錯多.dsf
# Copied: 06 - 依然.dsf → 06 依然.dsf
# Copied: 07 - 燒.dsf → 07 燒.dsf
# Copied: 08 - 不不不.dsf → 08 不不不.dsf
# Copied: 09 - 愛上一個不回家的人.dsf → 09 愛上一個不回家的人.dsf
# Copied: 10 - 情人的眼淚.dsf → 10 情人的眼淚.dsf
# Copied: 11 - 傾斜.dsf → 11 傾斜.dsf
# Copied: 12 - 你令我性感.dsf → 12 你令我性感.dsf
# ...
# </html>
#
# Processing: 张学友2024年60+演唱会歌单
# Error processing F:\Albums\张学友2024年60+演唱会歌单: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b1b4b9584c7',t:'MTc0NjEyMTAxMC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: Atmosphere
# Error processing F:\Albums\Atmosphere: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b1d1a4504f9',t:'MTc0NjEyMTAxMC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: Sasha Alex Sloan
# Error processing F:\Albums\Sasha Alex Sloan: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b1eacd1de13',t:'MTc0NjEyMTAxMS4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: 张学友《试音学友DXD》[WAV]
# Error processing F:\Albums\张学友《试音学友DXD》[WAV]: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b205b350952',t:'MTc0NjEyMTAxMS4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: 黄伟文
# Error processing F:\Albums\黄伟文: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b253e9dddbc',t:'MTc0NjEyMTAxMi4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Adele] 19
# Error processing F:\Albums\[Adele] 19: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b270fe485b5',t:'MTc0NjEyMTAxMi4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Adele] 21
# Error processing F:\Albums\[Adele] 21: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b28dd7d04d4',t:'MTc0NjEyMTAxMi4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Adele] 25
# Error processing F:\Albums\[Adele] 25: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b2a9d7a84bb',t:'MTc0NjEyMTAxMy4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Adele] Make You Feel My Love
# Error processing F:\Albums\[Adele] Make You Feel My Love: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b2c3bc6dd3a',t:'MTc0NjEyMTAxMy4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Adele] Rolling in the Deep (Explicit)
# Error processing F:\Albums\[Adele] Rolling in the Deep (Explicit): <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b2e1afa85b2',t:'MTc0NjEyMTAxMy4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Ariana Grande] Dangerous Woman
# Error processing F:\Albums\[Ariana Grande] Dangerous Woman: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b2fee59851e',t:'MTc0NjEyMTAxMy4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Ariana Grande] Positions (Deluxe)
# Error processing F:\Albums\[Ariana Grande] Positions (Deluxe): <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b317d2d109f',t:'MTc0NjEyMTAxNC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
#
# Processing: [Ariana Grande] thank u, next
# Error processing F:\Albums\[Ariana Grande] thank u, next: <html>
# <head><title>401 Authorization Required</title></head>
# <body>
# <center><h1>401 Authorization Required</h1></center>
# <hr><center>openresty/1.27.4</center>
# <script>(function(){function c(){var b=a.contentDocument||a.contentWindow.document;if(b){var d=b.createElement('script');d.innerHTML="window.__CF$cv$params={r:'93910b3349dfdd32',t:'MTc0NjEyMTAxNC4wMDAwMDA='};var a=document.createElement('script');a.nonce='';a.src='/cdn-cgi/challenge-platform/scripts/jsd/main.js';document.getElementsByTagName('head')[0].appendChild(a);";b.getElementsByTagName('head')[0].appendChild(d)}}if(document.body){var a=document.createElement('iframe');a.height=1;a.width=1;a.style.position='absolute';a.style.top=0;a.style.left=0;a.style.border='none';a.style.visibility='hidden';document.body.appendChild(a);if('loading'!==document.readyState)c();else if(window.addEventListener)document.addEventListener('DOMContentLoaded',c);else{var e=document.onreadystatechange||function(){};document.onreadystatechange=function(b){e(b);'loading'!==document.readyState&&(document.onreadystatechange=e,c())}}}})();</script></body>
# </html>
